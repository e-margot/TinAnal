# %% [markdown]
# <a href="https://colab.research.google.com/github/e-margot/TinAnal/blob/main/Convert_json_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json

# %%
import pandas as pd

# %%
import pandas as pd

with open('/content/drive/MyDrive/TinAnal/women.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

df.to_csv('/content/drive/MyDrive/TinAnal/women.csv', encoding='utf-8', index=False)

# %%
women = pd.read_csv('/content/drive/MyDrive/TinAnal/women.csv')

# %%
women
# Out:
#                            id        name  is_verified  \
# 0    62e13a41c27068010043fc1b         Evr         True
# 1    62ee25b401fd790100354525        Anna        False
# 2    628e4f5b9486220100784892       Alina        False
# 3    5dc7e16f30bdf601001f16b0       Дарья        False
# 4    613d2872ecc1fe0100189693        Таня        False
# ..                        ...         ...          ...
# 495  632197f8edb6ed010040aa9c  Aleksandra        False
# 496  6183b6de5566a10100ea28a9       Мария        False
# 497  627229c64b13430100f34268        Анна        False
# 498  62eebb55cc7a2b01007125e0      Ксения         True
# 499  6154192a8408f90100720b6f    Анжелика         True
#
#                                            description  birth_date  age  \
# 0    Влюблена в жизнь\nМожет быть влюблюсь в тебя 🤭...  2000-09-18   21
# 1                                                  NaN  1987-09-18   34
# 2    Интроверт\n\nИзначальная цель - общение, дальш...  1994-09-18   27
# 3                                                  NaN  1985-09-18   36
# 4                       Есть двое детей 6 лет и 11 лет  1984-09-18   37
# ..                                                 ...         ...  ...
# 495                                                NaN  1991-09-18   30
# 496  Водолей♒\n@mrs.krizh\n\nВысокая, если на каблу...  1988-09-18   33
# 497  Открыта к знакомствам.\n\nВо избежание недопон...  1992-09-18   29
# 498  Живу и работаю без графика. \nГулять, вкусно е...  1989-09-18   32
# 499                 Высокая 176) \nхаризматичная . Лев  1989-09-18   32
#
#      hide_age  is_traveling gender  show_gender_on_profile  has_social  \
# 0       False           0.0  woman                   False        True
# 1       False           NaN  woman                    True       False
# 2       False           1.0  woman                    True       False
# 3       False           0.0  woman                   False       False
# 4       False           NaN  woman                   False       False
# ..        ...           ...    ...                     ...         ...
# 495     False           0.0  woman                    True       False
# 496     False           NaN  woman                   False       False
# 497     False           NaN  woman                    True       False
# 498     False           NaN  woman                   False       False
# 499     False           0.0  woman                    True       False
#
#     social_connections                                          interests  \
# 0        ['instagram']  [{'id': 'it_2289', 'name': 'Инвестирование', '...
# 1                   []  [{'id': 'it_2016', 'name': 'Танцы', 'is_common...
# 2                   []  [{'id': 'it_58', 'name': 'Занятия на свежем во...
# 3                   []                                                 []
# 4                   []  [{'id': 'it_23', 'name': 'Спорт', 'is_common':...
# ..                 ...                                                ...
# 495                 []                                                 []
# 496                 []  [{'id': 'it_31', 'name': 'Ходьба', 'is_common'...
# 497                 []  [{'id': 'it_2017', 'name': 'Музей', 'is_common...
# 498                 []  [{'id': 'it_28', 'name': 'Чтение', 'is_common'...
# 499                 []  [{'id': 'it_1', 'name': 'Кофе', 'is_common': T...
#
#                                                   jobs  \
# 0                                                   []
# 1                                                   []
# 2               [{'title': {'name': 'Самозанятость'}}]
# 3                                                   []
# 4    [{'company': {'name': 'Росатом'}, 'title': {'n...
# ..                                                 ...
# 495                                                 []
# 496                                                 []
# 497                                                 []
# 498                        [{'title': {'name': 'ИП'}}]
# 499                                                 []
#
#                                                schools  \
# 0                                                   []
# 1                                                   []
# 2    [{'name': 'Санкт-Петербургский институт эконом...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 495                                                 []
# 496                               [{'name': 'Высшее'}]
# 497                                                 []
# 498                                                 []
# 499                                                 []
#
#                    sexual_orientations  hide_distance  \
# 0                                   []          False
# 1                                   []          False
# 2    [{'id': 'str', 'name': 'Гетеро'}]           True
# 3                                   []          False
# 4                                   []          False
# ..                                 ...            ...
# 495  [{'id': 'str', 'name': 'Гетеро'}]          False
# 496  [{'id': 'str', 'name': 'Гетеро'}]          False
# 497                                 []          False
# 498                                 []          False
# 499  [{'id': 'str', 'name': 'Гетеро'}]          False
#
#                                                options  \
# 0    [{'id': 'de_1', 'name': 'Знак зодиака', 'selec...
# 1    [{'id': 'de_1', 'name': 'Знак зодиака', 'selec...
# 2    [{'id': 'de_1', 'name': 'Знак зодиака', 'selec...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 495                                                 []
# 496  [{'id': 'de_1', 'name': 'Знак зодиака', 'selec...
# 497  [{'id': 'de_11', 'name': 'Курение', 'selection...
# 498  [{'id': 'de_3', 'name': 'Питомцы', 'selections...
# 499                                                 []
#
#                                                 photos
# 0    [{'id': 'df586273-e9c4-4fb8-92bb-0b44d3d596a5'...
# 1    [{'id': '7a30ab29-7948-41aa-88e2-94023a59e5db'...
# 2    [{'id': '1fc99cc2-1791-4602-adce-0c7f29636a51'...
# 3    [{'id': 'e32b1730-1869-4e44-954f-cfc46849258d'...
# 4    [{'id': '5e4fd958-4c68-41f5-8b06-3c79dfe01b7c'...
# ..                                                 ...
# 495  [{'id': '408a9a05-2744-4537-92da-5eebe3b641e7'...
# 496  [{'id': '349ac7b7-d007-400f-b8d1-f810a9cf97af'...
# 497  [{'id': '5aa94812-32e9-4249-939f-19058b863fc5'...
# 498  [{'id': '14c22632-d197-4bfd-b14a-f996f228a457'...
# 499  [{'id': '4c60cb26-4b52-4d8c-b4e0-b69207b8bc1c'...
#
# [500 rows x 19 columns]

# %%
f = open('/content/drive/MyDrive/TinAnal/women.json', encoding='utf-8')
ph = []
interests = []
data = json.load(f)
for i in data:
    de = []
    for j in i['options']:
      de.append(j['id'])
    for n in j['selections']:
      for m in i['photos']:
        ph.append(m['filename'])
      for inter in i['interests']:
        interests.append(inter['name'])
      with open('/content/drive/MyDrive/TinAnal/women_2_1.json', 'r+') as file:
        file_data = json.load(file)
        if 'de_11' in de:
          if j['id'] == 'de_11':
            if not interests:
              new = {'id': i['id'], 'age': i['age'], 'has_social': i['has_social'], 'gender': i['gender'], 'is_smoke': n['name'], 'interests': ['None'],'photos': ph}
            else:
              new = {'id': i['id'], 'age': i['age'], 'has_social': i['has_social'], 'gender': i['gender'], 'is_smoke': n['name'], 'interests': interests,'photos': ph}
        else:
          if not interests:
            new = {'id': i['id'], 'age': i['age'], 'has_social': i['has_social'], 'gender': i['gender'], 'is_smoke': 'None', 'interests': ['None'], 'photos': ph}
          else:
            new = {'id': i['id'], 'age': i['age'], 'has_social': i['has_social'], 'gender': i['gender'], 'is_smoke': 'None', 'interests': interests, 'photos': ph}
        file_data.append(new)
        file.seek(0)
        json.dump(file_data, file, indent = 4, ensure_ascii=False)
        ph.clear()
        interests.clear()


f.close()

# %%
import pandas as pd

with open('/content/drive/MyDrive/TinAnal/women_2_1.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

df.to_csv('/content/drive/MyDrive/TinAnal/women_2_1.csv', encoding='utf-8', index=False)

# %%
with open('/content/drive/MyDrive/TinAnal/men_2.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

df.to_csv('/content/drive/MyDrive/TinAnal/men_2.csv', encoding='utf-8', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/TinAnal/WOMEN.csv')

# %%
df_w
# Out:
#                            id  age  has_social gender is_smoke  \
# 0    62e13a41c27068010043fc1b   21        True  woman  Не курю
# 1    62ee25b401fd790100354525   34       False  woman     None
# 2    628e4f5b9486220100784892   27       False  woman  Не курю
# 3    5dc7e16f30bdf601001f16b0   36       False  woman     None
# 4    613d2872ecc1fe0100189693   37       False  woman     None
# ..                        ...  ...         ...    ...      ...
# 495  632197f8edb6ed010040aa9c   30       False  woman     None
# 496  6183b6de5566a10100ea28a9   33       False  woman  Не курю
# 497  627229c64b13430100f34268   29       False  woman  Не курю
# 498  62eebb55cc7a2b01007125e0   32       False  woman  Не курю
# 499  6154192a8408f90100720b6f   32       False  woman     None
#
#                                              interests  \
# 0    ['Инвестирование', 'Медитация', 'Спорт', 'Путе...
# 1    ['Танцы', 'Балет', 'Активный образ жизни', 'Сп...
# 2    ['Занятия на свежем воздухе', 'Путешествия', '...
# 3                                                 None
# 4    ['Спорт', 'Тренировки', 'Чай', 'Фильмы', 'Фото...
# ..                                                 ...
# 495                                               None
# 496     ['Ходьба', 'Бег', 'Фильмы', 'Чтение', 'Спорт']
# 497          ['Музей', 'Инвестирование', 'Фотография']
# 498                         ['Чтение', 'Кофе', 'Вино']
# 499  ['Кофе', 'Покупки', 'Вино', 'Музыка', 'Плавание']
#
#                                                 photos
# 0    ['df586273-e9c4-4fb8-92bb-0b44d3d596a5.jpg', '...
# 1    ['7a30ab29-7948-41aa-88e2-94023a59e5db.jpg', '...
# 2    ['1fc99cc2-1791-4602-adce-0c7f29636a51.jpg', '...
# 3    ['e32b1730-1869-4e44-954f-cfc46849258d.jpg', '...
# 4    ['5e4fd958-4c68-41f5-8b06-3c79dfe01b7c.jpg', '...
# ..                                                 ...
# 495       ['408a9a05-2744-4537-92da-5eebe3b641e7.jpg']
# 496  ['349ac7b7-d007-400f-b8d1-f810a9cf97af.jpg', '...
# 497  ['5aa94812-32e9-4249-939f-19058b863fc5.jpg', '...
# 498  ['14c22632-d197-4bfd-b14a-f996f228a457.jpg', '...
# 499  ['4c60cb26-4b52-4d8c-b4e0-b69207b8bc1c.jpg', '...
#
# [500 rows x 7 columns]

# %%
# her we define the threshhold or our age groups
age_groups = [0, 20, 25, 30, 35, 40, 55, 100]

# and for convenience we give each of them a handy label
age_group_names = ['<20', '21-25', '26-30', '31-35', '36-40', '41-55', '>55']

# %%
df['Age group'] = pd.cut(
    df['age'], bins=age_groups, labels=age_group_names)

df
# Out:
#                            id  age  has_social gender is_smoke  \
# 0    62e13a41c27068010043fc1b   21        True  woman  Не курю
# 1    62ee25b401fd790100354525   34       False  woman     None
# 2    628e4f5b9486220100784892   27       False  woman  Не курю
# 3    5dc7e16f30bdf601001f16b0   36       False  woman     None
# 4    613d2872ecc1fe0100189693   37       False  woman     None
# ..                        ...  ...         ...    ...      ...
# 495  632197f8edb6ed010040aa9c   30       False  woman     None
# 496  6183b6de5566a10100ea28a9   33       False  woman  Не курю
# 497  627229c64b13430100f34268   29       False  woman  Не курю
# 498  62eebb55cc7a2b01007125e0   32       False  woman  Не курю
# 499  6154192a8408f90100720b6f   32       False  woman     None
#
#                                              interests  \
# 0    ['Инвестирование', 'Медитация', 'Спорт', 'Путе...
# 1    ['Танцы', 'Балет', 'Активный образ жизни', 'Сп...
# 2    ['Занятия на свежем воздухе', 'Путешествия', '...
# 3                                                 None
# 4    ['Спорт', 'Тренировки', 'Чай', 'Фильмы', 'Фото...
# ..                                                 ...
# 495                                               None
# 496     ['Ходьба', 'Бег', 'Фильмы', 'Чтение', 'Спорт']
# 497          ['Музей', 'Инвестирование', 'Фотография']
# 498                         ['Чтение', 'Кофе', 'Вино']
# 499  ['Кофе', 'Покупки', 'Вино', 'Музыка', 'Плавание']
#
#                                                 photos  flower  smoker    pet  \
# 0    ['df586273-e9c4-4fb8-92bb-0b44d3d596a5.jpg', '...    True    True  False
# 1    ['7a30ab29-7948-41aa-88e2-94023a59e5db.jpg', '...    True    True  False
# 2    ['1fc99cc2-1791-4602-adce-0c7f29636a51.jpg', '...    True   False  False
# 3    ['e32b1730-1869-4e44-954f-cfc46849258d.jpg', '...   False    True  False
# 4    ['5e4fd958-4c68-41f5-8b06-3c79dfe01b7c.jpg', '...   False    True  False
# ..                                                 ...     ...     ...    ...
# 495       ['408a9a05-2744-4537-92da-5eebe3b641e7.jpg']   False   False  False
# 496  ['349ac7b7-d007-400f-b8d1-f810a9cf97af.jpg', '...    True    True  False
# 497  ['5aa94812-32e9-4249-939f-19058b863fc5.jpg', '...   False   False  False
# 498  ['14c22632-d197-4bfd-b14a-f996f228a457.jpg', '...    True   False  False
# 499  ['4c60cb26-4b52-4d8c-b4e0-b69207b8bc1c.jpg', '...    True   False  False
#
#      cell phone   alco    car    emo Age group
# 0         False  False  False  False     21-25
# 1         False  False  False  False     31-35
# 2          True  False   True  False     26-30
# 3          True  False   True   True     36-40
# 4          True   True  False   True     36-40
# ..          ...    ...    ...    ...       ...
# 495       False  False  False  False     26-30
# 496       False  False  False   True     31-35
# 497       False  False  False   True     26-30
# 498        True   True   True   True     31-35
# 499        True  False   True  False     31-35
#
# [500 rows x 15 columns]

# %%
df_m['Age group'] = pd.cut(
    df_m['age'], bins=age_groups, labels=age_group_names)

df_m
# Out:
#                            id  age  has_social gender          is_smoke  \
# 0    62fe27ea55229101001c7147   43       False    man              None
# 1    595140c4dd1c974f11da5a94   25       False    man           Не курю
# 2    629d4c36a2d0f10100d1c5fc   27       False    man  Курю за компанию
# 3    632411ecbb27b00100cd28df   33       False    man              None
# 4    62f2ae346dc4b2010029a7a9   27        True    man              None
# ..                        ...  ...         ...    ...               ...
# 524  62e6f8f49c2e7d010002a23a   32       False    man              Курю
# 525  611836cd8063e80100ac87ed   36       False    man              None
# 526  5931abdf41264cb432532e8c   30        True    man              None
# 527  58fc52033c272dcb4251bf97   35       False    man              None
# 528  615e84c783c6940100941795   52       False    man              None
#
#                                              interests  \
# 0        ['Бег', 'Хоккей', 'Спорт', 'Рыбалка', 'Вино']
# 1    ['Музыка', 'Спорт', 'Пропустить стаканчик', 'Н...
# 2                           ['Бег', 'Музей', 'Фильмы']
# 3    ['Просмотр сериалов', 'Соцсети', 'Занятия в по...
# 4    ['Дети 90-х', 'Чтение', 'Кулинария', 'Футбол',...
# ..                                                 ...
# 524                  ['Кофе', 'Фильмы', 'Путешествия']
# 525  ['Кофе', 'Вино', 'Музыка', 'Покупки', 'Instagr...
# 526                                               None
# 527  ['Спорт', 'Путешествия', 'Музыка', 'Комедия', ...
# 528  ['Ходьба', 'Чтение', 'Искусство', 'Политика', ...
#
#                                                 photos Age group
# 0    ['3ab12e5b-98f0-4f23-8958-5f07d8ed8fe6.jpg', '...     41-55
# 1    ['a6393026-88d7-4aef-8284-30c70264731d.jpg', '...     21-25
# 2    ['84acf117-2025-4a6b-9f8b-b9d8d04ff43f.jpg', '...     26-30
# 3    ['7b8cff27-3fe3-4c1d-95a8-4d2d6b4d48bf.jpg', '...     31-35
# 4    ['251090ae-82b1-4a5a-89e9-bcfa38dc1732.jpg', '...     26-30
# ..                                                 ...       ...
# 524  ['8402473b-2c0c-45ce-9f22-b3e6bd071949.jpg', '...     31-35
# 525  ['f95e66c8-dac9-4eda-8d56-764f29303c52.jpg', '...     36-40
# 526  ['f7febaae-dd00-41a9-8d8c-f3d75264985a.jpg', '...     26-30
# 527  ['6c0ac217-599d-435e-9746-7ccdf2eda942.jpg', '...     31-35
# 528  ['cac2dc9f-71dd-444b-97e6-8199bff6a4ac.jpg', '...     41-55
#
# [529 rows x 8 columns]

# %%
df_w.groupby('is_smoke')['is_smoke'].count()
# Out:
# is_smoke
# None                 255
# Курю                  17
# Курю за компанию      11
# Курю, когда выпью      3
# Не курю              214
# Name: is_smoke, dtype: int64

# %%
is_smoke = df.groupby(['is_smoke', 'Age group'])['is_smoke'].count()

# %% [markdown]
# bin anal

# %%
is_smoke.to_csv('/content/drive/MyDrive/TinAnal/anal_women_is_smoke.csv')

# %%
smoker = df.groupby(['smoker', 'Age group'])['smoker'].count()

# %%
flower = df.groupby(['flower', 'Age group'])['flower'].count()

# %%
pet = df.groupby(['pet', 'Age group'])['pet'].count()

# %%
cell_phone = df.groupby(['cell phone', 'Age group'])['cell phone'].count()

# %%
alco = df.groupby(['alco', 'Age group'])['alco'].count()

# %%
car = df.groupby(['car', 'Age group'])['car'].count()

# %%
emo = df.groupby(['emo', 'Age group'])['emo'].count()

# %%
has_social = df.groupby(['has_social', 'Age group'])['has_social'].count()

# %%
smoker.to_frame()
flower.to_frame()
pet.to_frame()
cell_phone.to_frame()
alco.to_frame()
car.to_frame()
emo.to_frame()
has_social.to_frame()

# %%
frames = [smoker, flower, pet, cell_phone, alco, car, emo, has_social]

# %%
res = pd.concat(frames, axis = 1, join = "inner")

# %%
res
# Out:
#                  smoker  flower  pet  cell phone  alco  car  emo  has_social
#       Age group
# False <20             7      11   19           8    17   18    9          16
#       21-25          38      40   68          38    67   64   38          64
#       26-30          53      60  101          67    98   95   32          96
#       31-35          70      89  166         111   156  147   47         162
#       36-40          55      82  134          85   131  125   34         133
#       41-55           4       3   10           5    10   10    4           9
#       >55             0       0    0           0     0    0    0           0
# True  <20            12       8    0          11     2    1   10           3
#       21-25          30      28    0          30     1    4   30           4
#       26-30          48      41    0          34     3    6   69           5
#       31-35          97      78    1          56    11   20  120           5
#       36-40          80      53    1          50     4   10  101           2
#       41-55           6       7    0           5     0    0    6           1
#       >55             0       0    0           0     0    0    0           0

# %%
res.to_csv('/content/drive/MyDrive/TinAnal/anal_women.csv')

# %% [markdown]
# # interests

# %%
from ast import literal_eval
df = pd.read_csv('/content/drive/MyDrive/TinAnal/women_2_1.csv', converters={'interests': literal_eval})

# %%
df['Age group'] = pd.cut(
    df['age'], bins=age_groups, labels=age_group_names)

df
# Out:
#                            id  age  has_social gender is_smoke  \
# 0    62e13a41c27068010043fc1b   21        True  woman  Не курю
# 1    62ee25b401fd790100354525   34       False  woman     None
# 2    628e4f5b9486220100784892   27       False  woman  Не курю
# 3    5dc7e16f30bdf601001f16b0   36       False  woman     None
# 4    613d2872ecc1fe0100189693   37       False  woman     None
# ..                        ...  ...         ...    ...      ...
# 495  632197f8edb6ed010040aa9c   30       False  woman     None
# 496  6183b6de5566a10100ea28a9   33       False  woman  Не курю
# 497  627229c64b13430100f34268   29       False  woman  Не курю
# 498  62eebb55cc7a2b01007125e0   32       False  woman  Не курю
# 499  6154192a8408f90100720b6f   32       False  woman     None
#
#                                              interests  \
# 0    [Инвестирование, Медитация, Спорт, Путешествия...
# 1    [Танцы, Балет, Активный образ жизни, Спортзал,...
# 2    [Занятия на свежем воздухе, Путешествия, Инвес...
# 3                                               [None]
# 4         [Спорт, Тренировки, Чай, Фильмы, Фотография]
# ..                                                 ...
# 495                                             [None]
# 496               [Ходьба, Бег, Фильмы, Чтение, Спорт]
# 497                [Музей, Инвестирование, Фотография]
# 498                               [Чтение, Кофе, Вино]
# 499            [Кофе, Покупки, Вино, Музыка, Плавание]
#
#                                                 photos Age group
# 0    ['df586273-e9c4-4fb8-92bb-0b44d3d596a5.jpg', '...     21-25
# 1    ['7a30ab29-7948-41aa-88e2-94023a59e5db.jpg', '...     31-35
# 2    ['1fc99cc2-1791-4602-adce-0c7f29636a51.jpg', '...     26-30
# 3    ['e32b1730-1869-4e44-954f-cfc46849258d.jpg', '...     36-40
# 4    ['5e4fd958-4c68-41f5-8b06-3c79dfe01b7c.jpg', '...     36-40
# ..                                                 ...       ...
# 495       ['408a9a05-2744-4537-92da-5eebe3b641e7.jpg']     26-30
# 496  ['349ac7b7-d007-400f-b8d1-f810a9cf97af.jpg', '...     31-35
# 497  ['5aa94812-32e9-4249-939f-19058b863fc5.jpg', '...     26-30
# 498  ['14c22632-d197-4bfd-b14a-f996f228a457.jpg', '...     31-35
# 499  ['4c60cb26-4b52-4d8c-b4e0-b69207b8bc1c.jpg', '...     31-35
#
# [500 rows x 8 columns]

# %%
for i, l in enumerate(df["interests"]):
  print("list",i,"is",type(l))

# %%
w_dict = {}
for i in df["interests"]:
    for j in i:
        if j not in w_dict:
            w_dict[j] = 1
        else:
            w_dict[j] += 1

# %%
def to_1D(series):
 return pd.Series([x for _list in series for x in _list])

# %%
data_int = to_1D(df['interests']).value_counts()

# %%
data_int
# Out:
# Путешествия              169
# Чтение                    97
# None                      96
# Фильмы                    83
# Спорт                     72
#                         ...
# Винтажная мода             1
# Спортивная гимнастика      1
# Мир во всем мире           1
# Хип-хоп                    1
# Кроссовки                  1
# Length: 178, dtype: int64

# %%
type(data_int)
# Out:
# pandas.core.series.Series

# %%
data_int.to_frame()
# Out:
#                          0
# Путешествия            169
# Чтение                  97
# None                    96
# Фильмы                  83
# Спорт                   72
# ...                    ...
# Винтажная мода           1
# Спортивная гимнастика    1
# Мир во всем мире         1
# Хип-хоп                  1
# Кроссовки                1
#
# [178 rows x 1 columns]

# %%
data_int = data_int.rename(columns={'index': 'interests', '0': 'count'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-5a9255c115e5> in <module>
# ----> 1 data_int = data_int.rename(columns={'index': 'interests', '0': 'count'})
#
# TypeError: rename() got an unexpected keyword argument 'columns'

# %%
data_int.to_csv('/content/drive/MyDrive/TinAnal/interests.csv')

# %%
inter = pd.read_csv('/content/drive/MyDrive/TinAnal/interests.csv')

# %%
inter = inter.rename(columns={'Unnamed: 0': 'interests', '0': 'count'})

# %%
inter.set_index('interests').T.to_dict('record')

# %%
smoker = df.groupby(['smoker', 'Age group'])['smoker'].count()

# %%
def boolean_df(item_lists, unique_items):
# Create empty dict
    bool_dict = {}
    
    # Loop through all the tags
    for i, item in enumerate(unique_items):
        
        # Apply boolean mask
        bool_dict[item] = item_lists.apply(lambda x: item in x)
            
    # Return the results as a dataframe
    return pd.DataFrame(bool_dict)

# %%
unique_items = {'Путешествия': 169,
  'Чтение': 97,
  'None': 96,
  'Фильмы': 83,
  'Спорт': 72,
  'Музыка': 68,
  'Кофе': 68,
  'Искусство': 63,
  'Тренировки': 45,
  'Вино': 45,
  'Танцы': 41,
  'Фотография': 38,
  'Спортзал': 37,
  'Ходьба': 37,
  'Языковой обмен': 36,
  'Активный образ жизни': 33,
  'Йога': 32,
  'Уход за собой': 29,
  'Выставки': 28,
  'Медитация': 28,
  'Кулинария': 23,
  'Музей': 22,
  'Мода': 22,
  'Бег': 22,
  'Чай': 19,
  'Настольные игры': 19,
  'Занятия на свежем воздухе': 17,
  'Духовность': 17,
  'Комедия': 16,
  'Netflix': 16,
  'Плавание': 15,
  'Горы': 15,
  'Instagram': 14,
  'Любитель(ница) собак': 14,
  'Предпринимательство': 14,
  'Тусовки': 13,
  'Пикник': 12,
  'Пеший туризм': 12,
  'Дети 90-х': 12,
  'Рисование': 12,
  'Инвестирование': 12,
  'Гурман(ка)': 11,
  'Рисовать': 11,
  'Татуировки': 11,
  'Любитель(ница) кошек': 11,
  'Домашние тренировки': 10,
  'Велоспорт': 10,
  'Сериалы': 10,
  'Покупки': 9,
  'Саморазвитие': 9,
  'Поэзия': 9,
  'Стендап-комедия': 9,
  'Караоке': 9,
  'Суши': 8,
  'Мемы': 8,
  'Самодельничество': 8,
  'Мороженое': 8,
  'Волонтёрство': 8,
  'Политика': 8,
  'Театр': 8,
  'Галереи искусств': 7,
  'Пробовать что-то новое': 7,
  'Дорожные путешествия': 7,
  'Походы': 7,
  'Рыбалка': 7,
  'Автомобили': 7,
  'Концерты': 7,
  'Выпечка': 7,
  'NFT': 6,
  'Просмотр сериалов': 6,
  'Макияж': 6,
  'Русский рок': 6,
  'Гурманский тур': 6,
  'Крафтовое пиво': 6,
  'Сёрфинг': 5,
  'Тур по барам': 5,
  'Сноубординг': 5,
  'Астрология': 5,
  'Дисней': 5,
  'Клубы': 5,
  'Стартапы': 4,
  'Электронная музыка': 4,
  'Подземелья и драконы': 4,
  'Изменение климата': 4,
  'Волейбол': 4,
  'Недвижимость': 4,
  'Садоводство': 4,
  'Бранч': 4,
  'Катание на лыжах': 4,
  'Походы по кафе': 3,
  'Скалолазание': 3,
  'Катание на роликах': 3,
  'Автогонки': 3,
  'Фридайвинг': 3,
  'Горячие источники': 3,
  'Квесты': 3,
  'Повар-любитель': 3,
  'Русский рэп': 3,
  'Мотоциклы': 3,
  'Коллекционирование': 3,
  'Блогинг': 3,
  'Аниме': 3,
  'Создание контента': 2,
  'Теннис': 2,
  'Хоккей': 2,
  'Спа': 2,
  'Баскетбол': 2,
  'Парусный спорт': 2,
  'Джин с тоником': 2,
  'YouTube': 2,
  'Литература': 2,
  'Кальян': 2,
  'Феминизм': 2,
  'Чай с шариками': 2,
  'Бокс': 2,
  'Защита природы': 2,
  'Спортсмен(ка)': 2,
  'Отдых в барах': 2,
  'Мотоспорт': 2,
  'TikTok': 2,
  'Кроссфит': 2,
  'Горячая йога': 2,
  'DAO (ДАО)': 2,
  'Рок': 2,
  'Рейв': 2,
  'Twitch': 2,
  'Писатель(ница)': 2,
  'Инвестиции': 2,
  'Marvel': 2,
  'Фестивали': 2,
  'Бадминтон': 1,
  'Поэтический слэм': 1,
  'Одежда из секонд-хенда': 1,
  'Уход за кожей': 1,
  'Коньки': 1,
  'Гольф': 1,
  'Права ЛГБТК+': 1,
  'Пилатес': 1,
  'Манга': 1,
  'Викторины в пабе': 1,
  'Пропустить стаканчик': 1,
  'Пляжные бары': 1,
  'Гимнастика': 1,
  'Военный': 1,
  'Барбекю': 1,
  'Фильмы о привидениях': 1,
  'Фондовая биржа': 1,
  'Сап-серфинг': 1,
  'Красиво писать': 1,
  'Метавселенная': 1,
  'Таро': 1,
  'Соцсети': 1,
  'Футбол': 1,
  'Реггетон': 1,
  'Жаркое из свинины': 1,
  'Косплей': 1,
  'Автоспорт': 1,
  'Викторины': 1,
  'Боевые искусства': 1,
  'Городские праздники': 1,
  'Бродвей': 1,
  'Холодный чай': 1,
  'Онлайн-игры': 1,
  'Harry Potter': 1,
  'Видеоблогинг': 1,
  'Скейтбординг': 1,
  'Балет': 1,
  'Кофейня': 1,
  'Тренировка Bodypump': 1,
  'Музыкальный инструмент': 1,
  'Научная фантастика': 1,
  'Кемпинг': 1,
  'Крикет': 1,
  'Винтажная мода': 1,
  'Спортивная гимнастика': 1,
  'Мир во всем мире': 1,
  'Хип-хоп': 1,
  'Кроссовки': 1}

# %%
interests_bool = boolean_df(df['interests'], unique_items.keys())

# %%
interests_bool
# Out:
#      Путешествия  Чтение   None  Фильмы  Спорт  Музыка   Кофе  Искусство  \
# 0           True   False  False   False   True   False  False      False
# 1          False   False  False   False  False   False  False      False
# 2           True   False  False   False  False   False  False      False
# 3          False   False   True   False  False   False  False      False
# 4          False   False  False    True   True   False  False      False
# ..           ...     ...    ...     ...    ...     ...    ...        ...
# 495        False   False   True   False  False   False  False      False
# 496        False    True  False    True   True   False  False      False
# 497        False   False  False   False  False   False  False      False
# 498        False    True  False   False  False   False   True      False
# 499        False   False  False   False  False    True   True      False
#
#      Тренировки   Вино  ...  Тренировка Bodypump  Музыкальный инструмент  \
# 0         False  False  ...                False                   False
# 1          True  False  ...                False                   False
# 2         False  False  ...                False                   False
# 3         False  False  ...                False                   False
# 4          True  False  ...                False                   False
# ..          ...    ...  ...                  ...                     ...
# 495       False  False  ...                False                   False
# 496       False  False  ...                False                   False
# 497       False  False  ...                False                   False
# 498       False   True  ...                False                   False
# 499       False   True  ...                False                   False
#
#      Научная фантастика  Кемпинг  Крикет  Винтажная мода  \
# 0                 False    False   False           False
# 1                 False    False   False           False
# 2                 False    False   False           False
# 3                 False    False   False           False
# 4                 False    False   False           False
# ..                  ...      ...     ...             ...
# 495               False    False   False           False
# 496               False    False   False           False
# 497               False    False   False           False
# 498               False    False   False           False
# 499               False    False   False           False
#
#      Спортивная гимнастика  Мир во всем мире  Хип-хоп  Кроссовки
# 0                    False             False    False      False
# 1                    False             False    False      False
# 2                    False             False    False      False
# 3                    False             False    False      False
# 4                    False             False    False      False
# ..                     ...               ...      ...        ...
# 495                  False             False    False      False
# 496                  False             False    False      False
# 497                  False             False    False      False
# 498                  False             False    False      False
# 499                  False             False    False      False
#
# [500 rows x 178 columns]

# %%
frame = [df, interests_bool]

# %%
res = pd.concat(frame, axis = 1, join = "inner")

# %%
res
# Out:
#                            id  age  has_social gender is_smoke  \
# 0    62e13a41c27068010043fc1b   21        True  woman  Не курю
# 1    62ee25b401fd790100354525   34       False  woman     None
# 2    628e4f5b9486220100784892   27       False  woman  Не курю
# 3    5dc7e16f30bdf601001f16b0   36       False  woman     None
# 4    613d2872ecc1fe0100189693   37       False  woman     None
# ..                        ...  ...         ...    ...      ...
# 495  632197f8edb6ed010040aa9c   30       False  woman     None
# 496  6183b6de5566a10100ea28a9   33       False  woman  Не курю
# 497  627229c64b13430100f34268   29       False  woman  Не курю
# 498  62eebb55cc7a2b01007125e0   32       False  woman  Не курю
# 499  6154192a8408f90100720b6f   32       False  woman     None
#
#                                              interests  \
# 0    [Инвестирование, Медитация, Спорт, Путешествия...
# 1    [Танцы, Балет, Активный образ жизни, Спортзал,...
# 2    [Занятия на свежем воздухе, Путешествия, Инвес...
# 3                                               [None]
# 4         [Спорт, Тренировки, Чай, Фильмы, Фотография]
# ..                                                 ...
# 495                                             [None]
# 496               [Ходьба, Бег, Фильмы, Чтение, Спорт]
# 497                [Музей, Инвестирование, Фотография]
# 498                               [Чтение, Кофе, Вино]
# 499            [Кофе, Покупки, Вино, Музыка, Плавание]
#
#                                                 photos Age group  Путешествия  \
# 0    ['df586273-e9c4-4fb8-92bb-0b44d3d596a5.jpg', '...     21-25         True
# 1    ['7a30ab29-7948-41aa-88e2-94023a59e5db.jpg', '...     31-35        False
# 2    ['1fc99cc2-1791-4602-adce-0c7f29636a51.jpg', '...     26-30         True
# 3    ['e32b1730-1869-4e44-954f-cfc46849258d.jpg', '...     36-40        False
# 4    ['5e4fd958-4c68-41f5-8b06-3c79dfe01b7c.jpg', '...     36-40        False
# ..                                                 ...       ...          ...
# 495       ['408a9a05-2744-4537-92da-5eebe3b641e7.jpg']     26-30        False
# 496  ['349ac7b7-d007-400f-b8d1-f810a9cf97af.jpg', '...     31-35        False
# 497  ['5aa94812-32e9-4249-939f-19058b863fc5.jpg', '...     26-30        False
# 498  ['14c22632-d197-4bfd-b14a-f996f228a457.jpg', '...     31-35        False
# 499  ['4c60cb26-4b52-4d8c-b4e0-b69207b8bc1c.jpg', '...     31-35        False
#
#      Чтение  ...  Тренировка Bodypump  Музыкальный инструмент  \
# 0     False  ...                False                   False
# 1     False  ...                False                   False
# 2     False  ...                False                   False
# 3     False  ...                False                   False
# 4     False  ...                False                   False
# ..      ...  ...                  ...                     ...
# 495   False  ...                False                   False
# 496    True  ...                False                   False
# 497   False  ...                False                   False
# 498    True  ...                False                   False
# 499   False  ...                False                   False
#
#      Научная фантастика  Кемпинг  Крикет  Винтажная мода  \
# 0                 False    False   False           False
# 1                 False    False   False           False
# 2                 False    False   False           False
# 3                 False    False   False           False
# 4                 False    False   False           False
# ..                  ...      ...     ...             ...
# 495               False    False   False           False
# 496               False    False   False           False
# 497               False    False   False           False
# 498               False    False   False           False
# 499               False    False   False           False
#
#      Спортивная гимнастика  Мир во всем мире  Хип-хоп  Кроссовки
# 0                    False             False    False      False
# 1                    False             False    False      False
# 2                    False             False    False      False
# 3                    False             False    False      False
# 4                    False             False    False      False
# ..                     ...               ...      ...        ...
# 495                  False             False    False      False
# 496                  False             False    False      False
# 497                  False             False    False      False
# 498                  False             False    False      False
# 499                  False             False    False      False
#
# [500 rows x 186 columns]

# %%
res.to_csv('/content/drive/MyDrive/TinAnal/bool_interests.csv')

# %%
res.groupby(['Путешествия', 'Age group'])['Путешествия'].count()
# Out:
# Путешествия  Age group
# False        <20           15
#              21-25         49
#              26-30         64
#              31-35        112
#              36-40         86
#              41-55          5
#              >55            0
# True         <20            4
#              21-25         19
#              26-30         37
#              31-35         55
#              36-40         49
#              41-55          5
#              >55            0
# Name: Путешествия, dtype: int64

# %%
df
# Out:
#                            id  age  has_social gender is_smoke  \
# 0    62e13a41c27068010043fc1b   21        True  woman  Не курю
# 1    62ee25b401fd790100354525   34       False  woman     None
# 2    628e4f5b9486220100784892   27       False  woman  Не курю
# 3    5dc7e16f30bdf601001f16b0   36       False  woman     None
# 4    613d2872ecc1fe0100189693   37       False  woman     None
# ..                        ...  ...         ...    ...      ...
# 495  632197f8edb6ed010040aa9c   30       False  woman     None
# 496  6183b6de5566a10100ea28a9   33       False  woman  Не курю
# 497  627229c64b13430100f34268   29       False  woman  Не курю
# 498  62eebb55cc7a2b01007125e0   32       False  woman  Не курю
# 499  6154192a8408f90100720b6f   32       False  woman     None
#
#                                              interests  \
# 0    [Инвестирование, Медитация, Спорт, Путешествия...
# 1    [Танцы, Балет, Активный образ жизни, Спортзал,...
# 2    [Занятия на свежем воздухе, Путешествия, Инвес...
# 3                                               [None]
# 4         [Спорт, Тренировки, Чай, Фильмы, Фотография]
# ..                                                 ...
# 495                                             [None]
# 496               [Ходьба, Бег, Фильмы, Чтение, Спорт]
# 497                [Музей, Инвестирование, Фотография]
# 498                               [Чтение, Кофе, Вино]
# 499            [Кофе, Покупки, Вино, Музыка, Плавание]
#
#                                                 photos Age group
# 0    ['df586273-e9c4-4fb8-92bb-0b44d3d596a5.jpg', '...     21-25
# 1    ['7a30ab29-7948-41aa-88e2-94023a59e5db.jpg', '...     31-35
# 2    ['1fc99cc2-1791-4602-adce-0c7f29636a51.jpg', '...     26-30
# 3    ['e32b1730-1869-4e44-954f-cfc46849258d.jpg', '...     36-40
# 4    ['5e4fd958-4c68-41f5-8b06-3c79dfe01b7c.jpg', '...     36-40
# ..                                                 ...       ...
# 495       ['408a9a05-2744-4537-92da-5eebe3b641e7.jpg']     26-30
# 496  ['349ac7b7-d007-400f-b8d1-f810a9cf97af.jpg', '...     31-35
# 497  ['5aa94812-32e9-4249-939f-19058b863fc5.jpg', '...     26-30
# 498  ['14c22632-d197-4bfd-b14a-f996f228a457.jpg', '...     31-35
# 499  ['4c60cb26-4b52-4d8c-b4e0-b69207b8bc1c.jpg', '...     31-35
#
# [500 rows x 8 columns]
